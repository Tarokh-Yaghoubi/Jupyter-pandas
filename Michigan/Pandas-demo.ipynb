# %%
import pandas as pd # import Pandas as pd to use it .

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId') # read the public csv file 
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname') # read the result schema .csv.

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.shape # number of Columns and Rows .
# Out:
# (83439, 47)

# %%
df.info # Information of the data frame .
# Out:
# <bound method DataFrame.info of                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# ...

# %%
clear

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', 15) # max columns to display | set to 15

# %%
pd.set_option('display.max_columns', 48) # set the option to see all the columns .
pd.set_option('display.max_rows', 47) # set the option to see all the rows .

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.rename(columns={'ConvertedCompYearly': 'SalaryUS'}, inplace=True)

# %%
df['SOAccount'] = df['SOAccount'].map({'Yes':True, 'No':False}).head(10)

# %%
pd.set_option('display.max_rows', 48)
pd.set_option('display.max_columns', 6)

# %%
schema_df.head # to see the top five values .
# Out:
# <bound method NDFrame.head of                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# ...

# %%
df.tail(10) # to see the last ten values .
# Out:
#                                 MainBranch  \
# ResponseId
# 83430          I code primarily as a hobby
# 83431       I am a developer by profession
# 83432       I am a developer by profession
# 83433       I am a developer by profession
# 83434       I am a developer by profession
# 83435       I am a developer by profession
# 83436       I am a developer by profession
# 83437       I am a developer by profession
# 83438       I am a developer by profession
# 83439       I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 83430                      Not employed, but looking for work
# 83431                                      Employed full-time
# 83432       Independent contractor, freelancer, or self-em...
# 83433                                      Employed full-time
# 83434       Independent contractor, freelancer, or self-em...
# 83435                                      Employed full-time
# ...

# %%
schema_df.head() # to print the first five rows 0:4 .
# Out:
#               qid                                           question  \
# qname
# S0          QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo    QID12                                  Browser Meta Info
# S1           QID1  <span style="font-size:22px; font-family: aria...
# MainBranch   QID2  Which of the following options best describes ...
# Employment  QID24  Which of the following best describes your cur...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# S1               False    DB       TB
# MainBranch        True    MC     SAVR
# Employment       False    MC     MAVR

# %%
df.columns # to print all the columns .
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'SalaryUS'],
#       dtype='object')

# %%
df['LanguageHaveWorkedWith'].value_counts().head(7)# to print all value counts of a column .
# Out:
# Python                                    1337
# HTML/CSS;JavaScript;Node.js;TypeScript     811
# Java                                       715
# HTML/CSS;JavaScript;PHP;SQL                674
# C#                                         597
# C#;HTML/CSS;JavaScript;SQL                 558
# HTML/CSS;JavaScript                        531
# Name: LanguageHaveWorkedWith, dtype: int64

# %%
df.loc[0:2, 'Employment':'UK_Country'] # Too print rows 0 to 2 and columns Employment to UK_Country .
# Out:
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State UK_Country
# ResponseId
# 1               NaN        NaN
# 2               NaN        NaN

# %%
schema_df.loc['CompTotal', 'question'] # to print 'CompTotal' 's Question text .
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in ${q://QID50/ChoiceGroup/SelectedChoicesTextEntry}? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
schema_df.sort_index(ascending=True) # to sort this by Alphabet | ascending is True .
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %%
schema_df.loc['YearsCode', 'question'] # to print 'YearsCode''s Question text .
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
schema_df.sort_index(ascending=False) # to print in vise verca .
# Out:
#                        qid                                           question  \
# qname
# YearsCodePro         QID34  NOT including education, how many years have y...
# YearsCode            QID32  Including any education, how many years have y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# Trans               QID153                    Do you identify as transgender?
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# ...

# %%
schema_df.sort_index(inplace=True) # Schema_df.sort | inplace=True is neccessary .

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %%
highest_salary = (df['SalaryUS'] > 90000)

# %%
df.loc[highest_salary, ['Country', 'Currency', 'LanguageHaveWorkedWith']].head(10)
# Out:
#                                                       Country  \
# ResponseId
# 19                                                  Singapore
# 32                                                     Israel
# 37                                   United States of America
# 38                                   United States of America
# 63                                   United States of America
# 65                                   United States of America
# 70          United Kingdom of Great Britain and Northern I...
# 76                                   United States of America
# 78                                                     Canada
# 81                                                 Uzbekistan
#
#                              Currency  \
# ResponseId
# 19              SGD\tSingapore dollar
# 32            ILS\tIsraeli new shekel
# 37          USD\tUnited States dollar
# 38          USD\tUnited States dollar
# 63          USD\tUnited States dollar
# ...

# %%
python_coder = (df['LanguageHaveWorkedWith'] == "Python") & (df['Country'] == "Germany")

# %%
df.loc[python_coder, ['Country', 'Currency', 'Sexuality', 'LanguageHaveWorkedWith', 'CompTotal']].head(10)
# Out:
#             Country           Currency                Sexuality  \
# ResponseId
# 796         Germany                NaN        Prefer not to say
# 1644        Germany  EUR European Euro  Straight / Heterosexual
# 3392        Germany                NaN  Straight / Heterosexual
# 3425        Germany  EUR European Euro           Bisexual;Queer
# 4306        Germany  EUR European Euro  Straight / Heterosexual
# 4397        Germany  EUR European Euro  Straight / Heterosexual
# 5130        Germany  EUR European Euro  Straight / Heterosexual
# 5639        Germany                NaN        Prefer not to say
# 5669        Germany  EUR European Euro  Straight / Heterosexual
# 6450        Germany  EUR European Euro                      NaN
#
#            LanguageHaveWorkedWith  CompTotal
# ResponseId
# 796                        Python        NaN
# 1644                       Python        NaN
# 3392                       Python        NaN
# 3425                       Python     3465.0
# ...

# %%
df[python_coder].value_counts()
# Out:
# Series([], dtype: int64)

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %%
df.sort_values(by=['Country', 'SalaryUS'], inplace=True, ascending=[True,False])

# %%
df[['Country', 'SalaryUS']].head(10)
# Out:
#                 Country    SalaryUS
# ResponseId
# 65400       Afghanistan  30468516.0
# 22667       Afghanistan    155496.0
# 27199       Afghanistan     51804.0
# 31087       Afghanistan     23964.0
# 44641       Afghanistan     15132.0
# 11378       Afghanistan      9792.0
# 17487       Afghanistan      5448.0
# 51429       Afghanistan      4668.0
# 14883       Afghanistan      4200.0
# 17121       Afghanistan      3108.0

# %%
df['SalaryUS'].nlargest(10)
# Out:
# ResponseId
# 66911    45241312.0
# 65400    30468516.0
# 40587    21822250.0
# 28792    20000000.0
# 12701    19200000.0
# 9609     17500000.0
# 5306     15000000.0
# 12904    14411628.0
# 66489    12750000.0
# 7206     12500000.0
# Name: SalaryUS, dtype: float64

# %%
python = [df.nlargest(10, 'SalaryUS'), df['LanguageHaveWorkedWith']]

# %%
python
# Out:
# [                                                   MainBranch  \
#  ResponseId
#  66911                          I am a developer by profession
#  65400                          I am a developer by profession
#  40587                          I am a developer by profession
#  28792                          I am a developer by profession
#  12701                          I am a developer by profession
#  9609        I am not primarily a developer, but I write co...
#  5306                           I am a developer by profession
#  12904                          I am a developer by profession
#  66489                          I am a developer by profession
#  7206                           I am a developer by profession
#
#                                                     Employment  \
#  ResponseId
#  66911                                     I prefer not to say
#  65400                                      Employed full-time
# ...

# %%
df['SalaryUS'].head(10)
# Out:
# ResponseId
# 65400    30468516.0
# 22667      155496.0
# 27199       51804.0
# 31087       23964.0
# 44641       15132.0
# 11378        9792.0
# 17487        5448.0
# 51429        4668.0
# 14883        4200.0
# 17121        3108.0
# Name: SalaryUS, dtype: float64

# %%
df['SalaryUS'].median() # the median value of all of those
# Out:
# 56211.0

# %%
df.median()
# Out:
# CompTotal    67000.0
# SOAccount        1.0
# SalaryUS     56211.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal      SalaryUS
# count  4.718300e+04  4.684400e+04
# mean   2.119407e+69  1.184262e+05
# std    4.603702e+71  5.272944e+05
# min    0.000000e+00  1.000000e+00
# 25%    1.600000e+04  2.702500e+04
# 50%    6.700000e+04  5.621100e+04
# 75%    1.400000e+05  1.000000e+05
# max    1.000000e+74  4.524131e+07

# %%
df['CompTotal'].count()
# Out:
# 47183

# %%
df['Employment']
# Out:
# ResponseId
# 65400                                   Employed full-time
# 22667    Independent contractor, freelancer, or self-em...
# 27199    Independent contractor, freelancer, or self-em...
# 31087                                   Employed full-time
# 44641                                   Employed full-time
#                                ...
# 75694                                   Student, full-time
# 76083                   Not employed, but looking for work
# 79302                                   Student, part-time
# 80997               Not employed, and not looking for work
# 82407                                   Employed part-time
# Name: Employment, Length: 83439, dtype: object

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time                                      53584
# Student, full-time                                      11781
# Independent contractor, freelancer, or self-employed     8041
# Not employed, but looking for work                       2961
# Employed part-time                                       2461
# Student, part-time                                       2051
# Not employed, and not looking for work                   1228
# I prefer not to say                                       890
# Retired                                                   326
# Name: Employment, dtype: int64

# %%
schema_df.loc['LearnCode', 'question']
# Out:
# 'How did you learn to code? Select all that apply.'

# %%
df['LearnCode'].value_counts(normalize=True).head(5)
# Out:
# School                                                                           0.087292
# Other online resources (ex: videos, blogs, etc)                                  0.042212
# Books / Physical media                                                           0.040464
# School;Books / Physical media                                                    0.037800
# Other online resources (ex: videos, blogs, etc);School;Books / Physical media    0.029423
# Name: LearnCode, dtype: float64

# %%
df['Country'].value_counts().head()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
# Name: Country, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Canada')
# Out:
#                                                    MainBranch  \
# ResponseId
# 25103                          I am a developer by profession
# 59555       I am not primarily a developer, but I write co...
# 62514                          I am a developer by profession
# 21841                          I am a developer by profession
# 54794                          I am a developer by profession
# ...                                                       ...
# 83194       I used to be a developer by profession, but no...
# 83202       I used to be a developer by profession, but no...
# 83221                          I am a developer by profession
# 83250                          I am a developer by profession
# 83270                  I am a student who is learning to code
#
#                                                    Employment Country  ...  \
# ResponseId                                                             ...
# ...

# %%
filt = df['Country'] == 'Russian Federation'

# %%
df.loc[filt]['Employment'].value_counts(normalize=True)
# Out:
# Employed full-time                                      0.682313
# Independent contractor, freelancer, or self-employed    0.110204
# Student, full-time                                      0.074830
# Not employed, but looking for work                      0.038095
# Employed part-time                                      0.031293
# Student, part-time                                      0.030612
# Not employed, and not looking for work                  0.017007
# I prefer not to say                                     0.012245
# Retired                                                 0.003401
# Name: Employment, dtype: float64

# %%
country_grp['Employment'].value_counts(normalize=True).loc['Canada']
# Out:
# Employment
# Employed full-time                                      0.647723
# Student, full-time                                      0.157527
# Independent contractor, freelancer, or self-employed    0.090728
# Not employed, but looking for work                      0.029578
# Not employed, and not looking for work                  0.021934
# Employed part-time                                      0.018611
# Student, part-time                                      0.013958
# I prefer not to say                                     0.012629
# Retired                                                 0.007311
# Name: Employment, dtype: float64

# %%
country_grp['SalaryUS'].median().loc['Germany']
# Out:
# 64859.0

# %%
country_grp['SalaryUS'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     75631.000000
# mean      135732.563006
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'Canada'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 1593

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
python_coder
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# 83439    False
# Length: 83439, dtype: bool
